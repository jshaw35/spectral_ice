# %% [markdown]
# # Select variables from the CESM1LE dataset to compute ensemble average
#
# ### Handle multiple time frames and correct for weird CESM time convention
#
# Use bash cdo and nco (ncea).

# %%
# Where ensemble outputs are stored by variable
cesm1le_vardir="/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/monthly"

# %%
# scratch for work
scratch_dir="/glade/scratch/jonahshaw/"
# scratch for processed data
scratch_savedir="/glade/scratch/jonahshaw/processed/"

# %%
ls $scratch_savedir
# Out:
# b.e11.BRCP85C5CNBDRD.f09_g16.001-035_101-105.cam.h0.FLUTC.200601-208012.nc
# b.e11.BRCP85C5CNBDRD.f09_g16.001-035_101-105.cam.h0.FSNS.200601-208012.nc
# b.e11.BRCP85C5CNBDRD.f09_g16.001-035_101-105.cam.h0.FSNSC.200601-208012.nc
# b.e11.BRCP85C5CNBDRD.f09_g16.001-035_101-105.cam.h0.FSNTOAC.200601-208012.nc

# %%
# Variables to retreive
# cesm1le_vars=("ICEFRAC" "TS" "SOLIN" "FSNTOA" "FLUT" "TMQ")
# cesm1le_vars="ICEFRAC TS SOLIN FSNTOA FSNTOAC FLUT FLUTC TMQ FSNS FSNSC"
cesm1le_vars="FSNTOAC FLUTC FSNS FSNSC"

# %%
module load cdo
module load nco

# %%
cd $cesm1le_vardir/FLUT/

# %%
# iterate over variables of interest
for var in $cesm1le_vars
do 
    echo $var
    cd $cesm1le_vardir/$var/
    filepaths1=$(ls *B20TRC5CNBDRD*200512*.nc)
#     echo $filepaths
    for path in $(echo $filepaths1)
    do
        echo $path
        
        cdo shifttime,-1mo "$cesm1le_vardir/$var/$path" $scratch_dir/$path
        
#         break
    done
    
    # iterate over files with a different time period and select 1920-2005
    filepaths2=$(ls *B20TRC5CNBDRD*185001-200512*.nc)
    for path in $(echo $filepaths2)
    do
        echo $path
        
        cdo selyear,1920/2005 "$scratch_dir/$path" "$scratch_dir/$path"b
                
    done
    
    ls $scratch_dir*.ncb
    # ls $scratch_dir/*B20TRC5CNBDRD*192001-200512*.nc
    
    # Remember to remove ensemble members 106,107 since they don’t have RCP8.5 runs.
    rm $scratch_dir/*106* $scratch_dir/*107*
    ls $scratch_dir/*B20TRC5CNBDRD*192001-200512*.nc
    
    # compute ensemble average of corrected files and save to processed/ directory
    ncea $scratch_dir/*$var*.ncb $scratch_dir/*B20TRC5CNBDRD*$var*192001-200512*.nc $scratch_savedir/b.e11.B20TRC5CNBDRD.f09_g16.001-035_101-105.cam.h0.$var.192001-200512.nc
    
    # clean up scratch
    rm $scratch_dir/*$var*.nc
    rm $scratch_dir/*$var*.ncb
#     break
done
# Out:
# FSNTOAC
# b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.FSNTOAC.185001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 103535471 values from 16 variables over 1872 timesteps [4.06s 97MB].
# b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.25s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.003.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.39s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.004.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.28s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.005.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.32s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.006.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.88s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.007.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.21s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.008.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.54s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.009.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.24s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.010.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.19s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.011.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.27s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.012.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.35s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.013.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.51s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.014.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.50s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.015.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.27s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.016.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.26s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.017.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.30s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.018.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.50s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.019.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.15s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.020.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.33s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.021.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.18s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.022.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.28s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.023.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.23s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.024.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.23s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.025.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.30s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.026.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.41s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.027.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.39s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.028.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.41s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.029.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.18s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.030.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.35s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.031.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [4.16s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.032.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [4.48s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.033.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [4.46s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.034.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.38s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.035.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.39s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.101.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.28s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.102.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.31s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.103.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.41s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.104.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.50s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.105.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.98s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.106.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.88s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.107.cam.h0.FSNTOAC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.24s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.FSNTOAC.185001-200512.nc
# cdo    selyear: Processed 57077591 values from 16 variables over 1872 timesteps [2.54s 78MB].
# /glade/scratch/jonahshaw/b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.FSNTOAC.185001-200512.ncb
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.003.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.004.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.005.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.006.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.007.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.008.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.009.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.010.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.011.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.012.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.013.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.014.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.015.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.016.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.017.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.018.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.019.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.020.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.021.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.022.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.023.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.024.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.025.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.026.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.027.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.028.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.029.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.030.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.031.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.032.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.033.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.034.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.035.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.101.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.102.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.103.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.104.cam.h0.FSNTOAC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.105.cam.h0.FSNTOAC.192001-200512.nc
# FLUTC
# b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.FLUTC.185001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 103535471 values from 16 variables over 1872 timesteps [5.08s 97MB].
# b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.85s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.003.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.41s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.004.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.22s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.005.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.18s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.006.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.27s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.007.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.26s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.008.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.18s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.009.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.15s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.010.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.26s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.011.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.38s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.012.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.42s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.013.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.15s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.014.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.16s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.015.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.20s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.016.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.06s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.017.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.30s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.018.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.20s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.019.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.34s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.020.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.13s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.021.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.40s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.022.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.24s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.023.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.29s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.024.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.09s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.025.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.44s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.026.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.41s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.027.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.16s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.028.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.21s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.029.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.64s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.030.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.23s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.031.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.91s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.032.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [5.07s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.033.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.72s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.034.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.29s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.035.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.74s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.101.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.36s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.102.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.30s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.103.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.15s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.104.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.13s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.105.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.21s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.106.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.52s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.107.cam.h0.FLUTC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.26s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.FLUTC.185001-200512.nc
# cdo    selyear: Processed 57077591 values from 16 variables over 1872 timesteps [2.43s 78MB].
# /glade/scratch/jonahshaw/b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.FLUTC.185001-200512.ncb
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.003.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.004.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.005.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.006.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.007.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.008.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.009.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.010.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.011.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.012.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.013.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.014.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.015.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.016.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.017.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.018.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.019.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.020.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.021.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.022.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.023.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.024.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.025.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.026.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.027.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.028.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.029.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.030.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.031.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.032.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.033.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.034.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.035.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.101.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.102.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.103.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.104.cam.h0.FLUTC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.105.cam.h0.FLUTC.192001-200512.nc
# FSNS
# b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.FSNS.185001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 103535471 values from 16 variables over 1872 timesteps [5.19s 97MB].
# b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.61s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.003.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.72s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.004.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.71s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.005.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.64s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.006.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.80s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.007.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.79s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.008.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.14s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.009.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.76s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.010.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.81s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.011.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.81s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.012.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.74s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.013.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.62s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.014.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.68s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.015.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.69s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.016.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.66s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.017.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.82s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.018.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.68s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.019.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.95s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.020.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.72s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.021.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.56s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.022.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.68s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.023.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.79s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.024.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.23s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.025.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.74s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.026.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.20s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.027.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.10s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.028.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.21s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.029.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.07s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.030.cam.h0.FSNS.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# ...
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.80s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.009.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.98s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.010.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.47s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.011.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.52s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.012.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.51s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.013.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.40s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.014.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.94s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.015.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.48s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.016.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.89s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.017.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.71s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.018.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.40s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.019.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.50s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.020.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.51s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.021.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.54s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.022.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.43s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.023.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [3.03s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.024.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.46s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.025.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.55s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.026.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.78s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.027.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.54s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.028.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.62s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.029.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.74s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.030.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.70s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.031.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [4.41s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.032.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [4.33s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.033.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [4.16s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.034.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.53s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.035.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.56s 78MB].
# b.e11.B20TRC5CNBDRD.f09_g16.101.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.60s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.102.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.40s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.103.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.74s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.104.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.53s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.105.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.45s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.106.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.50s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.107.cam.h0.FSNSC.192001-200512.nc
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable date_written!
# Warning (cdf_check_variables): Unsupported data type (char/string), skipped variable time_written!
# cdo    shifttime: Processed 57077591 values from 16 variables over 1032 timesteps [2.58s 77MB].
# b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.FSNSC.185001-200512.nc
# cdo    selyear: Processed 57077591 values from 16 variables over 1872 timesteps [2.39s 78MB].
# /glade/scratch/jonahshaw/b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.FSNSC.185001-200512.ncb
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.003.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.004.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.005.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.006.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.007.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.008.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.009.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.010.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.011.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.012.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.013.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.014.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.015.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.016.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.017.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.018.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.019.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.020.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.021.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.022.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.023.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.024.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.025.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.026.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.027.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.028.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.029.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.030.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.031.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.032.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.033.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.034.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.035.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.101.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.102.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.103.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.104.cam.h0.FSNSC.192001-200512.nc
# /glade/scratch/jonahshaw//b.e11.B20TRC5CNBDRD.f09_g16.105.cam.h0.FSNSC.192001-200512.nc
